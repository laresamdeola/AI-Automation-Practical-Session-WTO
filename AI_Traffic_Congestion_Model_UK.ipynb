# %% [markdown]
# <a href="https://colab.research.google.com/github/laresamdeola/AI-Automation-Practical-Session-WTO/blob/main/AI_Traffic_Congestion_Model_UK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('region_traffic_by_vehicle_type.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   year                        341 non-null    int64
#  1   region_id                   341 non-null    int64
#  2   region_name                 341 non-null    object
#  3   region_ons_code             341 non-null    object
#  4   link_length_km              341 non-null    float64
#  5   link_length_miles           341 non-null    float64
#  6   pedal_cycles                341 non-null    float64
#  7   two_wheeled_motor_vehicles  341 non-null    float64
#  8   cars_and_taxis              341 non-null    float64
#  9   buses_and_coaches           341 non-null    float64
#  10  LGVs                        341 non-null    float64
#  11  all_HGVs                    341 non-null    float64
#  12  all_motor_vehicles          341 non-null    float64
# ...

# %%
data.drop(['region_ons_code'], axis=1, inplace=True)

# %%
data
# Out:
#      year  region_id               region_name  link_length_km  \
# 0    1993          1                South West        48751.55
# 1    1993          2             East Midlands        30681.75
# 2    1993          3                  Scotland        58532.65
# 3    1993          4                     Wales        32543.50
# 4    1993          5                North West        35952.60
# ..    ...        ...                       ...             ...
# 336  2023          7           East of England        39712.80
# 337  2023          8  Yorkshire and the Humber        31259.81
# 338  2023          9                South East        48374.07
# 339  2023         10             West Midlands        33278.63
# 340  2023         11                North East        16403.70
#
#      link_length_miles  pedal_cycles  two_wheeled_motor_vehicles  \
# 0             30292.81   228000000.0                 289900000.0
# 1             19064.76   199700000.0                 172800000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   year                        341 non-null    int64
#  1   region_id                   341 non-null    int64
#  2   region_name                 341 non-null    object
#  3   link_length_km              341 non-null    float64
#  4   link_length_miles           341 non-null    float64
#  5   pedal_cycles                341 non-null    float64
#  6   two_wheeled_motor_vehicles  341 non-null    float64
#  7   cars_and_taxis              341 non-null    float64
#  8   buses_and_coaches           341 non-null    float64
#  9   LGVs                        341 non-null    float64
#  10  all_HGVs                    341 non-null    float64
#  11  all_motor_vehicles          341 non-null    float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 32.1+ KB

# %%
data.describe().T
# Out:
#                             count          mean           std           min  \
# year                        341.0  2.008000e+03  8.957416e+00  1.993000e+03
# region_id                   341.0  6.000000e+00  3.166925e+00  1.000000e+00
# link_length_km              341.0  3.570254e+04  1.272603e+04  1.435045e+04
# link_length_miles           341.0  2.218453e+04  7.907586e+03  8.916960e+03
# pedal_cycles                341.0  2.814839e+08  1.443353e+08  7.820000e+07
# two_wheeled_motor_vehicles  341.0  2.540721e+08  1.325011e+08  5.030000e+07
# cars_and_taxis              341.0  2.167127e+10  8.079843e+09  7.676500e+09
# buses_and_coaches           341.0  2.586604e+08  8.177713e+07  7.430000e+07
# LGVs                        341.0  3.716729e+09  1.580092e+09  1.021900e+09
# all_HGVs                    341.0  1.537045e+09  6.221561e+08  4.028000e+08
# all_motor_vehicles          341.0  2.743778e+10  1.009799e+10  1.006980e+10
#
# ...

# %%
data.loc[:, 'region_name'].unique()
# Out:
# array(['South West', 'East Midlands', 'Scotland', 'Wales', 'North West',
#        'London', 'East of England', 'Yorkshire and the Humber',
#        'South East', 'West Midlands', 'North East'], dtype=object)

# %%
data.loc[:, 'year'].unique()
# Out:
# array([1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

data.loc[:, 'region_name'] = encoder.fit_transform(data.loc[:, 'region_name'].values.reshape(-1, 1))

# %%
'''
South West = 7.0
East Midlands = 0.0
Scotland = 5.0
Wales = 8.0
North West = 4.0
West Midlands = 9.0
East of England = 1.0
South East = 6.0
London = 2.0
North East = 3.0
Yorkshire and the Humber = 10.0
'''

# %%
data.loc[10:20, 'region_name']
# Out:
# 10     3.0
# 11     7.0
# 12     0.0
# 13     5.0
# 14     8.0
# 15     4.0
# 16     2.0
# 17     1.0
# 18    10.0
# 19     6.0
# 20     9.0
# Name: region_name, dtype: object

# %%
data.corr()
# Out:
#                                     year     region_id   region_name  \
# year                        1.000000e+00 -1.029907e-15  5.149535e-16
# region_id                  -1.029907e-15  1.000000e+00  1.818182e-01
# region_name                 5.149535e-16  1.818182e-01  1.000000e+00
# link_length_km              2.611206e-02 -4.465104e-01  2.476069e-01
# link_length_miles           2.611206e-02 -4.465104e-01  2.476069e-01
# pedal_cycles                3.313839e-01  1.176660e-01 -1.931773e-01
# two_wheeled_motor_vehicles  1.429269e-02 -6.847846e-02 -1.495257e-01
# cars_and_taxis              7.742710e-02  4.503747e-02  8.393545e-02
# buses_and_coaches          -4.027653e-01 -4.420021e-02 -3.892844e-02
# LGVs                        5.261861e-01  4.313579e-04  7.335758e-02
# all_HGVs                    1.570396e-02 -6.345486e-03  6.842255e-02
# all_motor_vehicles          1.421809e-01  3.445650e-02  8.057721e-02
#
# ...
